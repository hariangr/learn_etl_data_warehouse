# %%
import json
from flask import Response
from flask import Flask, render_template, request
import pickle
import flask
import os
import sqlite3
from IPython.core.display import JSON
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from transformer import get_lat, get_lng, remove_after_dot, scientific_notation_9_kelurahan_id_to_int, split_date_process_end, split_date_process_start

base_oltp = "./assets/oltp"

# %%
# ### Dimensi Kategori
dim_kategori = pd.read_excel(
    f"{base_oltp}/master_kategori.xlsx").set_index('category_id')
dim_kategori['category_is_food'] = dim_kategori['category_is_food'] == 1
dim_kategori['category_name'].to_list()
# Out:
# ['CAFE', 'JAJANAN', 'RESTAURANT', 'TOKO/SWALAYAN', 'WARUNG MAKAN']

# %%
# ### Dimensi Driver
dim_driver = pd.read_excel(
    f"{base_oltp}/master_driver.xlsx").set_index('user_id')
dim_driver['user_gender'] = dim_driver['user_gender'] == 'L'
dim_driver = dim_driver.rename(columns={'user_gender': 'is_male'})
dim_driver
# Out:
#                            user_name                               user_email  \
# user_id
# 108        Ana Maimunah Pertiwi S.H.      ana_maimunah_pertiwi_s_h_@gmail.com
# 87       Artanto Eman Wacana S.I.Kom  artanto_eman_wacana_s_i_kom@yahoo.co.id
# 75                   Atma Dasa Uwais              atma_dasa_uwais@gmail.co.id
# 96                     Bakda Gunawan                bakda_gunawan@yahoo.co.id
# 95                  Cengkal Marpaung             cengkal_marpaung@yahoo.co.id
# 86                Daliono Firgantoro             daliono_firgantoro@gmail.com
# 92                       Danu Januar                  danu_januar@gmail.co.id
# 89                      Dirja Mansur                 dirja_mansur@gmail.co.id
# 103                Eka Tira Haryanti            eka_tira_haryanti@yahoo.co.id
# 104        Faizah Shania Usamah S.T.      faizah_shania_usamah_s_t_@yahoo.com
# 83              Gaiman Hidayat S.Kom         gaiman_hidayat_s_kom@yahoo.co.id
# 107         Gasti Nadia Pratiwi S.Gz       gasti_nadia_pratiwi_s_gz@gmail.com
# 100            Halima Kani Purnawati          halima_kani_purnawati@yahoo.com
# 94               Harjo Karya Suwarno          harjo_karya_suwarno@gmail.co.id
# 98             Imam Abyasa Maheswara          imam_abyasa_maheswara@gmail.com
# 102                    Intan Nasyiah                  intan_nasyiah@yahoo.com
# 79              Jabal Prasetya S.Psi         jabal_prasetya_s_psi@yahoo.co.id
# 85                   Jarwadi Nababan              jarwadi_nababan@gmail.co.id
# 88               Jatmiko Waluyo S.Pd          jatmiko_waluyo_s_pd@gmail.co.id
# 99                   Joko Situmorang              joko_situmorang@yahoo.co.id
# 101           Kartika Winarsih S.Ked       kartika_winarsih_s_ked@yahoo.co.id
# 82                      Latif Marbun                   latif_marbun@yahoo.com
# 84                 Lukita Napitupulu            lukita_napitupulu@yahoo.co.id
# 77          Lukman Ganep Januar M.Ak     lukman_ganep_januar_m_ak@yahoo.co.id
# 93           Mahesa Tarihoran S.Farm        mahesa_tarihoran_s_farm@gmail.com
# 109             Maimunah Pudjiastuti         maimunah_pudjiastuti@gmail.co.id
# 81                      Manah Sirait                   manah_sirait@gmail.com
# 91                   Margana Pratama                margana_pratama@yahoo.com
# 78                    Maryadi Natsir               maryadi_natsir@yahoo.co.id
# 80                  Mursita Prasetya               mursita_prasetya@yahoo.com
# 76               Paiman Wacana S.Kom            paiman_wacana_s_kom@yahoo.com
# 105                Restu Yuniar S.Pt            restu_yuniar_s_pt@gmail.co.id
# 90                 Rusman Situmorang            rusman_situmorang@yahoo.co.id
# 97                   Waluyo Setiawan              waluyo_setiawan@gmail.co.id
# 106             Yunita Laras Pratiwi           yunita_laras_pratiwi@yahoo.com
#
#         user_birthdate  is_male  \
# user_id
# 108         1991-12-21    False
# 87          1983-05-25     True
# 75          1985-12-28     True
# 96          1995-05-26     True
# 95          1994-12-09     True
# 86          1995-12-01     True
# 92          1977-04-03     True
# 89          1987-12-02     True
# 103         1994-11-21    False
# 104         1979-10-19    False
# 83          1975-11-17     True
# 107         1992-09-01    False
# 100         1993-11-08    False
# 94          1981-09-21     True
# 98          1981-08-19     True
# 102         1993-04-23    False
# 79          1987-08-18     True
# 85          1984-06-01     True
# 88          1983-11-23     True
# 99          1982-12-20     True
# 101         1986-04-02    False
# 82          1993-10-06     True
# 84          2000-02-22     True
# 77          1976-07-26     True
# 93          1984-12-26     True
# 109         1988-02-05    False
# 81          1991-08-09     True
# 91          1995-12-24     True
# 78          1999-11-13     True
# 80          1987-03-29     True
# 76          1992-12-07     True
# 105         1989-03-18    False
# 90          1997-03-24     True
# 97          1978-07-27     True
# 106         1999-02-17    False
#
#                                               user_address  user_lat  \
# user_id
# 108                Jl. Pak Benceng No.C7,  Sungai Bangkong -0.052168
# 87                           Gang Ramin 5 No.76,  Tj. Hulu -0.029319
# 75                                    Gang Madani,  Pal IX -0.067330
# 96                          Gang Melati 2,  Sungai Beliung -0.008973
# 95                                Jl. Padat Karya,  Saigon -0.043819
# 86                              Jl. Perdana,  Parit Tokaya -0.073419
# 92                                    Pal IX,  Kakap River -0.061224
# 89                   masjid mujahid,  Jl. Putri Candramidi -0.037534
# 103                                   Pal IX,  Kakap River -0.062174
# 104                        Jl. Parit Leban,  Punggur Kecil -0.104739
# 83                                   Unnamed Road,  Pal IX -0.055718
# 107                  Jl. Parit Demang Dalam,  Parit Tokaya -0.068536
# 100                    Jl. Drs. Moh. Hatta,  Sungai Rengas -0.001530
# 94                             Unnamed Road,  Siantan Hulu -0.006513
# 98               Gg. Sentarum Jaya No.F8,  Sungai Bangkong -0.044151
# 102                            Punggur Kecil,  Kakap River -0.078472
# 79            Jl. Tabrani Ahmad No.17c,  Sungai Jawi Dalam -0.019835
# 85                        Jalan Bina Jaya No.7,  Kota Baru -0.062620
# 88                  Jl. Dharma Putra No.14,  Siantan Hilir  0.000156
# 99                             Gg. Makmur,  Siantan Tengah -0.003079
# 101                     Jalan Karya Syukri,  Punggur Kecil -0.098698
# 82                       Gg. Asia Jaya No.99a,  Pak Lanjut -0.068122
# 84                  Gg. Jaya Baru No.22a,  Sungai Bangkong -0.035267
# 77                                   Unnamed Road,  Pal IX -0.052272
# 93                             Jalan Mega Jaya,  Kota Baru -0.065487
# 109                        Jl. Yam Sabran No.96,  Tj. Hulu -0.025666
# 90       109.288573    6171030006      SUNGAI JAWI DALAM     PONTIANAK BARAT
# 97       109.278437    6171010006              KOTA BARU   PONTIANAK SELATAN
# 106      109.296576    6171030008         SUNGAI BELIUNG     PONTIANAK BARAT
#
#          fleet_id  fleet_merk fleet_type
# user_id
# 108             8      Toyota      MOBIL
# 87              1       Honda      MOTOR
# 75              6         TVS      MOTOR
# 96             17         KIA      MOBIL
# 95              1       Honda      MOBIL
# 86              1       Honda      MOTOR
# 92              2      Yamaha      MOTOR
# 89              4      Suzuki      MOTOR
# 103             7         BMW      MOTOR
# 104             7         BMW      MOTOR
# 83              1       Honda      MOTOR
# 107            19       Volvo      MOBIL
# 100             2      Yamaha      MOTOR
# 94              7         BMW      MOTOR
# 98             14        Audi      MOBIL
# 102             3    Kawasaki      MOTOR
# 79              7         BMW      MOTOR
# 85              4      Suzuki      MOTOR
# 88              3    Kawasaki      MOTOR
# 99              7         BMW      MOBIL
# 101             1       Honda      MOTOR
# 82              4      Suzuki      MOTOR
# 84              3    Kawasaki      MOTOR
# 77              7         BMW      MOTOR
# 93              6         TVS      MOTOR
# 109             1       Honda      MOBIL
# 81              7         BMW      MOTOR
# 91              1       Honda      MOTOR
# 78              2      Yamaha      MOTOR
# 80              6         TVS      MOTOR
# 76              6         TVS      MOTOR
# 105             3    Kawasaki      MOTOR
# 90              2      Yamaha      MOTOR
# 97             10  Mitsubishi      MOBIL
# 106             6         TVS      MOTOR

# %%
# ### Dimensi Kelurahan
dim_kelurahan = pd.read_excel(
    f"{base_oltp}/master_kelurahan.xlsx").set_index('kelurahan_id')

dim_merchant = pd.read_excel(f"{base_oltp}/master_merchant.xlsx").astype(
    {'kelurahan_id': 'str'}).set_index('merchant_id')
dim_merchant['kelurahan_id'] = dim_merchant['kelurahan_id'].apply(
    remove_after_dot)
# TODO: Hapus nan
dim_merchant
# Out:
#              category_id                    merchant_name  \
# merchant_id
# 266                    4                         Bakso 77
# 106                    3                       KFC SERDAM
# 286                    2  Warung Kopi & Kuliner Nusantara
# 20                     4                      Pondok Rasa
# 418                    1            Indomaret Jalan karet
# ...                  ...                              ...
# 261                    4              Rumah Makan Karunia
# 424                    1             Alfamart Imam Bonjol
# 425                    1          Indomaret Siantan Hilir
# 426                    1            Alfamart Siantan Hulu
# 62                     5                     Kuliner BPAS
#
#                                               merchant_address  \
# merchant_id
# 266          Jalan Mitra Indah Utama 8, Kalimantan Barat 78...
# 106          Komp. Lestari 2, Sungai Raya, Kabupaten Kubu R...
# 286                                 Jl. Sei. Raya Dalam No. 29
# 20           Jl. Purnama I No.7, Akcaya, Pontianak Sel., Ko...
# 418                                                   Jl Karet
# ...                                                        ...
# 261          Jl. Sepakat II No.2, Bansir Darat, Pontianak T...
# 424                                             Jl Imam Bonjol
# 425                                      Jl Gusti Situt Mahmud
# 426                                              Jl 28 Oktober
# 62           Gg. Selat Makassar, Siantan Tengah, Pontianak ...
#
#              merchant_address_lat merchant_address_lng kelurahan_id  \
# merchant_id
# 266                     -0.088364           109.349154          nan
# 106                     -0.077896            109.35664          nan
# 286                     -0.026330           109.342504          nan
# 20                      -0.050195              109.334   6171030001
# 418                     -0.009802           109.295136   6171030008
# ...                           ...                  ...          ...
# 261                     -0.061266           109.349946   6171011004
# 424                     -0.039971           109.345044   6171011003
# 425                     -0.013708           109.336138   6171040002
# 426                     -0.008582           109.361511   6171040004
# 62                      -0.016248           109.344718   6171040004
#
#              kelurahan_name      kecamatan_name
# merchant_id
# 266                     NaN                 NaN
# 106                     NaN                 NaN
# 286                     NaN                 NaN
# 20                 PAL LIMA     PONTIANAK BARAT
# 418          SUNGAI BELIUNG     PONTIANAK BARAT
# ...                     ...                 ...
# 261            BANSIR DARAT  PONTIANAK TENGGARA
# 424             BANSIR LAUT  PONTIANAK TENGGARA
# 425           SIANTAN HILIR     PONTIANAK UTARA
# 426            SIANTAN HULU     PONTIANAK UTARA
# 62             SIANTAN HULU     PONTIANAK UTARA
#
# [84 rows x 8 columns]

# %%
# ### Dimensi User
dim_user = pd.read_excel(f"{base_oltp}/master_user.xlsx").set_index('user_id')
dim_user['user_gender'] = dim_user['user_gender'] == 'L'
dim_user = dim_user.rename(columns={'user_gender': 'is_male'})
dim_user
# Out:
#                            user_name                               user_email  \
# user_id
# 47                     Aisyah Farida                aisyah_farida@gmail.co.id
# 55            Ajimin Aditya Pangestu         ajimin_aditya_pangestu@gmail.com
# 11                   Anita Mardhiyah                anita_mardhiyah@yahoo.com
# 8        Argono Daru Tarihoran S.Sos  argono_daru_tarihoran_s_sos@gmail.co.id
# 51                   Artawan Pranowo                artawan_pranowo@yahoo.com
# ...                              ...                                      ...
# 10                     Warta Pranowo                warta_pranowo@gmail.co.id
# 65                     Wisnu Mandala                wisnu_mandala@gmail.co.id
# 41                     Yance Riyanti                  yance_riyanti@yahoo.com
# 40                    Yulia Yulianti                 yulia_yulianti@gmail.com
# 42              Yunita Tiara Laksita           yunita_tiara_laksita@gmail.com
#
#         user_birthdate  is_male                                 user_address  \
# user_id
# 47          2003-10-28    False                   Jalur Cinday,  Batu Layang
# 55          2004-04-22     True                Unnamed Road,  Sungai Beliung
# 11          2002-03-13    False      jln puskesmas gg sejati 2,  Sungai Jawi
# 8           1987-02-08     True                  Jalan Bina Jaya,  Kota Baru
# 51          1991-05-07     True  Jl. Tabrani Ahmad No.50,  Sungai Jawi Dalam
# ...                ...      ...                                          ...
# 10          1989-05-30     True      Gg. Selamat 3 No.17,  Sungai Jawi Dalam
# 65          2001-07-28     True       Jl. Dharma Putra No.19,  Siantan Hilir
# 41          2000-08-25    False          Gg. Nurul Muslimin,  Siantan Tengah
# 40          1997-03-22    False                  Jl. Karya Baru No.4,  RT.03
# 42          1998-02-20    False      Jl. Selat Panjang No.357,  Siantan Hulu
#
#          user_lat    user_lng  kelurahan_id    kelurahan_name  \
# user_id
# 47       0.010186  109.313097    6171030001          PAL LIMA
# 55      -0.001745  109.293638    6171030007  SUNGAI JAWI LUAR
# 11      -0.025152  109.305623    6171030007  SUNGAI JAWI LUAR
# 8       -0.064516  109.310146    6171031004           MARIANA
# 51      -0.021350  109.300646    6171011004      BANSIR DARAT
# ...           ...         ...           ...               ...
# 10      -0.018620  109.321530    6171031001   SUNGAI BANGKONG
# 65      -0.002717  109.342878    6171040001       BATU LAYANG
# 41      -0.011712  109.352202    6171031001   SUNGAI BANGKONG
# 40      -0.050908  109.336643    6171020002    BANJAR SERASAN
# 42      -0.016558  109.376771    6171040001       BATU LAYANG
#
#              kecamatan_name
# user_id
# 47          PONTIANAK BARAT
# 55          PONTIANAK BARAT
# 11          PONTIANAK BARAT
# 8            PONTIANAK KOTA
# 51       PONTIANAK TENGGARA
# ...                     ...
# 10           PONTIANAK KOTA
# 65          PONTIANAK UTARA
# 41           PONTIANAK KOTA
# 40          PONTIANAK TIMUR
# 42          PONTIANAK UTARA
#
# [74 rows x 10 columns]

# %%
con = sqlite3.connect(f"{base_oltp}/dummy_ojol_transactions_raw_only.sqlite")
fact_transaction = pd.read_sql_query(
    f"SELECT * FROM dummy_ojol_transactions_raw_only_query_get_transaction_list_koto", con)
fact_transaction = fact_transaction.set_index('id')


date_start = fact_transaction.apply(
    lambda row: split_date_process_start(row), axis=1)
fact_transaction['date_start'] = pd.to_datetime(date_start)
date_end = fact_transaction.apply(
    lambda row: split_date_process_end(row), axis=1)
fact_transaction['date_end'] = pd.to_datetime(date_end)

# Ubah notasi science di kolom kelurahanid menjadi int64
fact_transaction['from_kelurahanid'] = fact_transaction['from_kelurahanid'].apply(
    scientific_notation_9_kelurahan_id_to_int)
fact_transaction['to_kelurahanid'] = fact_transaction['to_kelurahanid'].apply(
    scientific_notation_9_kelurahan_id_to_int)

# Split latlng from dan to


fact_transaction['transaction_from_lat'] = fact_transaction['transaction_from_latlng'].apply(
    get_lat).astype(float)
fact_transaction['transaction_from_lng'] = fact_transaction['transaction_from_latlng'].apply(
    get_lng).astype(float)
fact_transaction['transaction_to_lat'] = fact_transaction['transaction_to_latlng'].apply(
    get_lat).astype(float)
fact_transaction['transaction_to_lng'] = fact_transaction['transaction_to_latlng'].apply(
    get_lng).astype(float)

# Banyak ada yang formatnya tidak bener misal transaction_from_latlng "-0.03844709999999999,109.3272303 \t\t\t\t\t\t\..."
fact_transaction.loc[fact_transaction['transaction_from_latlng'].str.contains(
    "\t")]

fact_transaction = fact_transaction.drop('date_process', axis=1)
fact_transaction = fact_transaction.drop('transaction_from_latlng', axis=1)
fact_transaction = fact_transaction.drop('transaction_to_latlng', axis=1)
fact_transaction
# Out:
#         mode                                        from_alamat  \
# id
# 1617.0  BIKE                    Gang Ikhwan No.16,  Sungai Jawi
# 1297.0  FOOD  Neo Shabu-Shabu Steak & Shake, Johar, Jl. Joha...
# 1394.0  SHOP             Alfamart Pontianak Mall, Jl Teuku Umar
# 1120.0  FOOD  Parklife, Jl. Karimata No.64, Sungai Bangkong,...
# 2053.0   CAR        Jl. Tabrani Ahmad No.12,  Sungai Jawi Dalam
# ...      ...                                                ...
# 1242.0  FOOD  Pondok Ale-ale, Gg. Suka Damai No.21, Sungai B...
# 2911.0   CAR                                  Jl. Tani,  Saigon
#
#         transaction_from_lng  transaction_to_lat  transaction_to_lng
# id
# 1617.0            109.297753           -0.061345          109.305406
# 1297.0            109.329253           -0.028571          109.374953
# 1394.0            109.335633           -0.022623          109.319152
# 1120.0            109.326401           -0.063780          109.273496
# 2053.0            109.307568           -0.059239          109.273129
# ...                      ...                 ...                 ...
# 1242.0            109.325818           -0.057694          109.283237
# 2911.0            109.371125           -0.031017          109.295263
# 1779.0            109.345834           -0.027845          109.302605
# 1228.0            109.293303           -0.062233          109.332094
# 2133.0            109.323564           -0.052613          109.305974
#
# [1878 rows x 18 columns]

# %%
sort_quarterly = fact_transaction.groupby(
    fact_transaction['date_start'].dt.to_period('Q'))
simplify = {}
for key, it in sort_quarterly:
    simplify[str(key)] = it
# simplify

fact_transaction.describe()
# Out:
#        from_kelurahanid  to_kelurahanid  transaction_from_lat  \
# count      1.878000e+03    1.878000e+03           1878.000000
# mean       6.171024e+09    6.171024e+09             -0.073262
# std        1.076069e+04    1.103941e+04              0.505192
# min        6.171010e+09    6.171010e+09             -6.365364
# 25%        6.171011e+09    6.171011e+09             -0.046276
# 50%        6.171030e+09    6.171020e+09             -0.031178
# 75%        6.171031e+09    6.171031e+09             -0.018078
# max        6.171040e+09    6.171040e+09              0.048717
#
#        transaction_from_lng  transaction_to_lat  transaction_to_lng  \
# count           1878.000000         1878.000000         1878.000000
# mean             109.310201           -0.034424          109.323928
# std                0.200379            0.027589            0.031985
# min              106.833712           -0.117758          109.231879
# 25%              109.308190           -0.056933          109.304047
# 50%              109.328523           -0.032241          109.320632
# 75%              109.343623           -0.015075          109.347188
# max              109.410567            0.048517          109.414946
#
#        distance_rounded
# count       1878.000000
# mean          12.171624
# std           59.825153
# min            2.090000
# 25%            5.302500
# 50%            6.995000
# 75%            9.200000
# max          762.130000

# %%
def get_rounded_dist(cell):
    s = int(float(cell))
    return s

import matplotlib.pyplot as plt

fact_transaction['distance_rounded'] = fact_transaction['distance'].apply(get_rounded_dist)
    
plt.hist(fact_transaction['distance_rounded'])
# Out:
# (array([1866.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#           12.]),
#  array([  2.,  78., 154., 230., 306., 382., 458., 534., 610., 686., 762.]),
#  <BarContainer object of 10 artists>)

# %%
fact_transaction['distance_rounded']
# Out:
# id
# 1617.0     5
# 1297.0     7
# 1394.0     4
# 1120.0     8
# 2053.0     7
#           ..
# 1242.0     7
# 2911.0    10
# 1779.0     7
# 1228.0     7
# 2133.0     6
# Name: distance_rounded, Length: 1878, dtype: int64

# %%
sort_mode = fact_transaction.groupby(
    fact_transaction['mode'])
simplify_mode = {}
for key, it in sort_mode:
    simplify_mode[str(key)] = it

# %%
simplify_mode.keys()
# Out:
# dict_keys(['BIKE', 'CAR', 'FOOD', 'SHOP'])

# %%
# Amount Transaction Delivery
plt.figure(figsize=(10, 8))
plt.title("Amount Transaction Delivery IDR")
plt.xticks(rotation=90)
plt.hist(simplify[q]['amount_delivery'].to_list())
tmpfile = BytesIO()
plt.savefig(tmpfile, format='png')
graph_amount_trans = base64.b64encode(tmpfile.getvalue()).decode('utf-8')
